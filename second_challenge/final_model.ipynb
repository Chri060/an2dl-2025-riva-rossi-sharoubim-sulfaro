# %% [markdown]
# # U-Net - multi head

# %% [markdown]
# ## Description
#
# **Kaggle mean Intersection over Union** : 0.48733
#
# **Local test mean Intersection over Union**: 0.48866
#
# **Description**: Using multiple heads on the previously trained U-Net architecture
#
# **Motivation**: Learning more meaningful features even in the middle of the network, simplifying convergence and allowing better gradient flow

# %% [markdown]
# ## Google Drive - Connecting to the project

# %%
from google.colab import drive
import sys
drive.mount('/content/drive')
project_path = "/content/drive/MyDrive/Colab Notebooks/ANN/le acque del friuli - Homework 2"
# %cd {project_path}
sys.path.append(project_path)
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/ANN/le acque del friuli - Homework 2

# %% [markdown]
# ## Imports

# %%
# Set seed for reproducibility
seed = 42

# Import necessary libraries
import os

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(seed)
random.seed(seed)

# Import TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl

# Set seed for TensorFlow
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# Import other libraries
import os
import math
from PIL import Image
from keras import backend as K
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

import cv2

import utils

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline

from tensorflow.keras.metrics import MeanIoU

# %%
# Set batch size for training
BATCH_SIZE = 64

# Number of classes
NUM_CLASSES = 5

INPUT_SHAPE = (64,128,1)

# %% [markdown]
# ## Load Data

# %%
def color_img(image):
    image = (image * 255).astype(np.uint8)
    return cv2.applyColorMap(image, cv2.COLORMAP_RAINBOW) # https://docs.opencv.org/3.4/d3/d50/group__imgproc__colormap.html

# %%
# Load the dataset
data = np.load("dataset/cleaned_dataset.npz")
test_img = data['test_set']

# Split the dataset in images and labels array
X = data['images']
y = data['labels']
y = tfk.utils.to_categorical(y, num_classes=NUM_CLASSES)

# Split the dataset into training and validation (test is given)
train_img, test_img_local, train_lbl, test_lbl_local = train_test_split(X, y, test_size=0.2, random_state=seed)
train_img, val_img, train_lbl, val_lbl = train_test_split(train_img, train_lbl, test_size=0.2, random_state=seed)

# %%
# Create a dataset with batch and shuffle
def make_dataset(images,labels,batch_size, shuffle=True, augment=False, seed=None):
    dataset = tf.data.Dataset.from_tensor_slices((images,{'out1':labels, 'out2':labels, 'out3':labels}))

    if shuffle:
        dataset = dataset.shuffle(buffer_size=batch_size * 2, seed=seed)

    # Batch the data
    dataset = dataset.batch(batch_size, drop_remainder=False)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)

    return dataset

# %%
# Create the training dataset
train_dataset = make_dataset(
    train_img, train_lbl,
    batch_size=BATCH_SIZE,
    shuffle=True,
    augment=True,
    seed=seed
)

# Create the validation dataset
val_dataset = make_dataset(
    val_img, val_lbl,
    batch_size=BATCH_SIZE,
    shuffle=False,
    augment=False,
    seed=seed
)

# %% [markdown]
# ## Model Implementation

# %%
# Building block for the U-Net architecture
def unet_block(input_tensor, filters, kernel_size=3, activation='relu', stack=2, name=''):
    # Initialise the input tensor
    x = input_tensor

    # Apply a sequence of Conv2D, Batch Normalisation, and Activation layers for the specified number of stacks
    for i in range(stack):
        x = tfkl.Conv2D(filters, kernel_size=kernel_size, padding='same', name=name + 'conv' + str(i + 1))(x)
        x = tfkl.BatchNormalization(name=name + 'bn' + str(i + 1))(x)
        x = tfkl.Activation(activation, name=name + 'activation' + str(i + 1))(x)

    # Return the transformed tensor
    return x

# %%
# Definition of the model
def get_unet_model(input_shape=INPUT_SHAPE, num_classes=NUM_CLASSES, seed=seed):
    tf.random.set_seed(seed)
    input_layer = tfkl.Input(shape=input_shape, name='input_layer')


    # Downsampling path
    down_block_1 = unet_block(input_layer, 32, name='down_block1_')
    d1 = tfkl.MaxPooling2D()(down_block_1)

    down_block_2 = unet_block(d1, 64, name='down_block2_')
    d2 = tfkl.MaxPooling2D()(down_block_2)

    down_block_3 = unet_block(d2, 128, name='down_block3_')
    d3 = tfkl.MaxPooling2D()(down_block_3)

    # Bottleneck
    bottleneck = unet_block(d3, 256, name='bottleneck')

    # Upsampling path
    u1 = tfkl.UpSampling2D()(bottleneck)
    u1 = tfkl.Concatenate()([u1, down_block_3])
    u1 = unet_block(u1, 128, name='up_block1_')

    u2 = tfkl.UpSampling2D()(u1)
    u2 = tfkl.Concatenate()([u2, down_block_2])
    u2 = unet_block(u2, 64, name='up_block2_')

    u3 = tfkl.UpSampling2D()(u2)
    u3 = tfkl.Concatenate()([u3, down_block_1])
    u3 = unet_block(u3, 32, name='up_block3_')


    # Output Layers
    up1 = tfkl.Conv2DTranspose(filters=64, kernel_size=3, strides=2**2, padding='same')(u1)
    out1 = tfkl.Conv2D(num_classes, kernel_size=1, padding='same', activation="softmax", name='out1')(up1)

    up2 = tfkl.Conv2DTranspose(filters=32, kernel_size=3, strides=2**1, padding='same')(u2)
    out2 = tfkl.Conv2D(num_classes, kernel_size=1, padding='same', activation="softmax", name='out2')(up2)

    out3 = tfkl.Conv2D(num_classes, kernel_size=1, padding='same', activation="softmax", name='out3')(u3)

    model = tf.keras.Model(inputs=input_layer, outputs=[out1,out2,out3], name='UNet')
    return model

# %%
# Model contruction
model = get_unet_model()

# Print a detailed summary of the model with expanded nested layers and trainable parameters.
model.summary(expand_nested=False, show_trainable=True)
# Out:
# Model: "UNet"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)           ┃ Output Shape         ┃      Param # ┃ Connected to        ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ input_layer            │ (None, 64, 128, 1)   │            0 │ -                   │    -    │
# │ (InputLayer)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_conv1      │ (None, 64, 128, 32)  │          320 │ input_layer[0][0]   │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_bn1        │ (None, 64, 128, 32)  │          128 │ down_block1_conv1[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_activatio… │ (None, 64, 128, 32)  │            0 │ down_block1_bn1[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_conv2      │ (None, 64, 128, 32)  │        9,248 │ down_block1_activa… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_bn2        │ (None, 64, 128, 32)  │          128 │ down_block1_conv2[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_activatio… │ (None, 64, 128, 32)  │            0 │ down_block1_bn2[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ max_pooling2d          │ (None, 32, 64, 32)   │            0 │ down_block1_activa… │    -    │
# │ (MaxPooling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_conv1      │ (None, 32, 64, 64)   │       18,496 │ max_pooling2d[0][0] │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_bn1        │ (None, 32, 64, 64)   │          256 │ down_block2_conv1[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_activatio… │ (None, 32, 64, 64)   │            0 │ down_block2_bn1[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_conv2      │ (None, 32, 64, 64)   │       36,928 │ down_block2_activa… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_bn2        │ (None, 32, 64, 64)   │          256 │ down_block2_conv2[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_activatio… │ (None, 32, 64, 64)   │            0 │ down_block2_bn2[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ max_pooling2d_1        │ (None, 16, 32, 64)   │            0 │ down_block2_activa… │    -    │
# │ (MaxPooling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block3_conv1      │ (None, 16, 32, 128)  │       73,856 │ max_pooling2d_1[0]… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block3_bn1        │ (None, 16, 32, 128)  │          512 │ down_block3_conv1[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block3_activatio… │ (None, 16, 32, 128)  │            0 │ down_block3_bn1[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block3_conv2      │ (None, 16, 32, 128)  │      147,584 │ down_block3_activa… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block3_bn2        │ (None, 16, 32, 128)  │          512 │ down_block3_conv2[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block3_activatio… │ (None, 16, 32, 128)  │            0 │ down_block3_bn2[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ max_pooling2d_2        │ (None, 8, 16, 128)   │            0 │ down_block3_activa… │    -    │
# │ (MaxPooling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckconv1        │ (None, 8, 16, 256)   │      295,168 │ max_pooling2d_2[0]… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckbn1          │ (None, 8, 16, 256)   │        1,024 │ bottleneckconv1[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckactivation1  │ (None, 8, 16, 256)   │            0 │ bottleneckbn1[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckconv2        │ (None, 8, 16, 256)   │      590,080 │ bottleneckactivati… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckbn2          │ (None, 8, 16, 256)   │        1,024 │ bottleneckconv2[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckactivation2  │ (None, 8, 16, 256)   │            0 │ bottleneckbn2[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_sampling2d          │ (None, 16, 32, 256)  │            0 │ bottleneckactivati… │    -    │
# │ (UpSampling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ concatenate            │ (None, 16, 32, 384)  │            0 │ up_sampling2d[0][0… │    -    │
# │ (Concatenate)          │                      │              │ down_block3_activa… │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_conv1        │ (None, 16, 32, 128)  │      442,496 │ concatenate[0][0]   │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_bn1          │ (None, 16, 32, 128)  │          512 │ up_block1_conv1[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_activation1  │ (None, 16, 32, 128)  │            0 │ up_block1_bn1[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_conv2        │ (None, 16, 32, 128)  │      147,584 │ up_block1_activati… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_bn2          │ (None, 16, 32, 128)  │          512 │ up_block1_conv2[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_activation2  │ (None, 16, 32, 128)  │            0 │ up_block1_bn2[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_sampling2d_1        │ (None, 32, 64, 128)  │            0 │ up_block1_activati… │    -    │
# │ (UpSampling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ concatenate_1          │ (None, 32, 64, 192)  │            0 │ up_sampling2d_1[0]… │    -    │
# │ (Concatenate)          │                      │              │ down_block2_activa… │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_conv1        │ (None, 32, 64, 64)   │      110,656 │ concatenate_1[0][0] │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_bn1          │ (None, 32, 64, 64)   │          256 │ up_block2_conv1[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_activation1  │ (None, 32, 64, 64)   │            0 │ up_block2_bn1[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_conv2        │ (None, 32, 64, 64)   │       36,928 │ up_block2_activati… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_bn2          │ (None, 32, 64, 64)   │          256 │ up_block2_conv2[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_activation2  │ (None, 32, 64, 64)   │            0 │ up_block2_bn2[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_sampling2d_2        │ (None, 64, 128, 64)  │            0 │ up_block2_activati… │    -    │
# │ (UpSampling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ concatenate_2          │ (None, 64, 128, 96)  │            0 │ up_sampling2d_2[0]… │    -    │
# │ (Concatenate)          │                      │              │ down_block1_activa… │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block3_conv1        │ (None, 64, 128, 32)  │       27,680 │ concatenate_2[0][0] │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block3_bn1          │ (None, 64, 128, 32)  │          128 │ up_block3_conv1[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block3_activation1  │ (None, 64, 128, 32)  │            0 │ up_block3_bn1[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block3_conv2        │ (None, 64, 128, 32)  │        9,248 │ up_block3_activati… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block3_bn2          │ (None, 64, 128, 32)  │          128 │ up_block3_conv2[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ conv2d_transpose       │ (None, 64, 128, 64)  │       73,792 │ up_block1_activati… │    Y    │
# │ (Conv2DTranspose)      │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ conv2d_transpose_1     │ (None, 64, 128, 32)  │       18,464 │ up_block2_activati… │    Y    │
# │ (Conv2DTranspose)      │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block3_activation2  │ (None, 64, 128, 32)  │            0 │ up_block3_bn2[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ out1 (Conv2D)          │ (None, 64, 128, 5)   │          325 │ conv2d_transpose[0… │    Y    │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ out2 (Conv2D)          │ (None, 64, 128, 5)   │          165 │ conv2d_transpose_1… │    Y    │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ out3 (Conv2D)          │ (None, 64, 128, 5)   │          165 │ up_block3_activati… │    Y    │
# └────────────────────────┴──────────────────────┴──────────────┴─────────────────────┴─────────┘
#  Total params: 2,044,815 (7.80 MB)
#  Trainable params: 2,041,999 (7.79 MB)
#  Non-trainable params: 2,816 (11.00 KB)

# %% [markdown]
# ## Training

# %%
# Set learning rate for the optimiser
LEARNING_RATE = 1e-3

# Set early stopping patience threshold
PATIENCE = 10

# Set plateauing patience threshold
LR_PATIENCE = 5

# Set maximum number of training epochs
EPOCHS = 1000

# %%
# Model compilation with Adam as optimizer and CategoricalFocalCrossentropy as loss functions
model.compile(
    optimizer=tf.keras.optimizers.Adam(LEARNING_RATE),
    loss={
        'out1': tfk.losses.CategoricalFocalCrossentropy(alpha=2),
        'out2': tfk.losses.CategoricalFocalCrossentropy(alpha=2),
        'out3': tfk.losses.CategoricalFocalCrossentropy(alpha=2)
    },
    loss_weights={
        'out1': 1,
        'out2': 0.5,
        'out3': 0.5
    },
    metrics=[
        [tfk.metrics.OneHotMeanIoU(NUM_CLASSES,ignore_class=0, name='meanIoU')],
        [tfk.metrics.OneHotMeanIoU(NUM_CLASSES,ignore_class=0, name='meanIoU')],
        [tfk.metrics.OneHotMeanIoU(NUM_CLASSES,ignore_class=0, name='meanIoU')]
        ]
    )

# %%
# Setup callbacks, implementing early stopping as a technique to avoid overfitting
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_out3_meanIoU',
    mode='max',
    patience=PATIENCE,
    restore_best_weights=True
)

# Reduce learning rate on plateau
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_out3_meanIoU',
    mode='max',
    factor=0.1,
    patience=LR_PATIENCE,
    min_lr=1e-6
)

# Combine the callbacks into a list
callbacks = [early_stopping, reduce_lr]

# %%
# Train the model
history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=val_dataset,
    callbacks=callbacks,
    verbose=1,
).history
# Out:
# Epoch 1/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 44s 537ms/step - loss: 3.5095 - out1_loss: 1.7344 - out1_meanIoU: 0.1356 - out2_loss: 0.8074 - out2_meanIoU: 0.1710 - out3_loss: 0.9667 - out3_meanIoU: 0.1979 - val_loss: 6.7844 - val_out1_loss: 2.3943 - val_out1_meanIoU: 0.1152 - val_out2_loss: 1.7751 - val_out2_meanIoU: 0.1153 - val_out3_loss: 2.6276 - val_out3_meanIoU: 0.0383 - learning_rate: 0.0010
# Epoch 2/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 2.4740 - out1_loss: 1.3970 - out1_meanIoU: 0.2257 - out2_loss: 0.5199 - out2_meanIoU: 0.3149 - out3_loss: 0.5567 - out3_meanIoU: 0.3180 - val_loss: 5.3643 - val_out1_loss: 1.7606 - val_out1_meanIoU: 0.1761 - val_out2_loss: 1.1072 - val_out2_meanIoU: 0.1857 - val_out3_loss: 2.5054 - val_out3_meanIoU: 0.1442 - learning_rate: 0.0010
# Epoch 3/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 2.4446 - out1_loss: 1.3695 - out1_meanIoU: 0.2188 - out2_loss: 0.5287 - out2_meanIoU: 0.3075 - out3_loss: 0.5460 - out3_meanIoU: 0.3091 - val_loss: 13.0201 - val_out1_loss: 3.1953 - val_out1_meanIoU: 0.1307 - val_out2_loss: 4.0400 - val_out2_meanIoU: 0.1057 - val_out3_loss: 5.7944 - val_out3_meanIoU: 0.1022 - learning_rate: 0.0010
# Epoch 4/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 2.1763 - out1_loss: 1.2504 - out1_meanIoU: 0.2411 - out2_loss: 0.4568 - out2_meanIoU: 0.3500 - out3_loss: 0.4691 - out3_meanIoU: 0.3524 - val_loss: 3.5347 - val_out1_loss: 1.6364 - val_out1_meanIoU: 0.1902 - val_out2_loss: 0.8933 - val_out2_meanIoU: 0.2546 - val_out3_loss: 1.0057 - val_out3_meanIoU: 0.2600 - learning_rate: 0.0010
# Epoch 5/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 2.2027 - out1_loss: 1.2486 - out1_meanIoU: 0.2267 - out2_loss: 0.4709 - out2_meanIoU: 0.3251 - out3_loss: 0.4836 - out3_meanIoU: 0.3285 - val_loss: 3.7109 - val_out1_loss: 1.7201 - val_out1_meanIoU: 0.1701 - val_out2_loss: 0.9794 - val_out2_meanIoU: 0.1755 - val_out3_loss: 1.0149 - val_out3_meanIoU: 0.1830 - learning_rate: 0.0010
# Epoch 6/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 2.1546 - out1_loss: 1.2221 - out1_meanIoU: 0.2350 - out2_loss: 0.4631 - out2_meanIoU: 0.3310 - out3_loss: 0.4695 - out3_meanIoU: 0.3334 - val_loss: 3.8100 - val_out1_loss: 1.7537 - val_out1_meanIoU: 0.1640 - val_out2_loss: 0.9638 - val_out2_meanIoU: 0.1995 - val_out3_loss: 1.0819 - val_out3_meanIoU: 0.1823 - learning_rate: 0.0010
# Epoch 7/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 2.0259 - out1_loss: 1.1728 - out1_meanIoU: 0.2428 - out2_loss: 0.4247 - out2_meanIoU: 0.3570 - out3_loss: 0.4277 - out3_meanIoU: 0.3675 - val_loss: 3.6318 - val_out1_loss: 1.6662 - val_out1_meanIoU: 0.2012 - val_out2_loss: 0.9902 - val_out2_meanIoU: 0.2304 - val_out3_loss: 0.9844 - val_out3_meanIoU: 0.2440 - learning_rate: 0.0010
# Epoch 8/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 1.9436 - out1_loss: 1.1344 - out1_meanIoU: 0.2538 - out2_loss: 0.4041 - out2_meanIoU: 0.3691 - out3_loss: 0.4053 - out3_meanIoU: 0.3783 - val_loss: 2.1900 - val_out1_loss: 1.2021 - val_out1_meanIoU: 0.2392 - val_out2_loss: 0.4861 - val_out2_meanIoU: 0.3101 - val_out3_loss: 0.5040 - val_out3_meanIoU: 0.3166 - learning_rate: 0.0010
# Epoch 9/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 1.9659 - out1_loss: 1.1408 - out1_meanIoU: 0.2505 - out2_loss: 0.4117 - out2_meanIoU: 0.3612 - out3_loss: 0.4130 - out3_meanIoU: 0.3648 - val_loss: 2.9054 - val_out1_loss: 1.4581 - val_out1_meanIoU: 0.2037 - val_out2_loss: 0.7267 - val_out2_meanIoU: 0.2426 - val_out3_loss: 0.7196 - val_out3_meanIoU: 0.2483 - learning_rate: 0.0010
# Epoch 10/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 1.7981 - out1_loss: 1.0805 - out1_meanIoU: 0.2686 - out2_loss: 0.3583 - out2_meanIoU: 0.4034 - out3_loss: 0.3592 - out3_meanIoU: 0.4102 - val_loss: 2.9098 - val_out1_loss: 1.4768 - val_out1_meanIoU: 0.1896 - val_out2_loss: 0.6910 - val_out2_meanIoU: 0.1979 - val_out3_loss: 0.7505 - val_out3_meanIoU: 0.2038 - learning_rate: 0.0010
# Epoch 11/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 1.8947 - out1_loss: 1.1146 - out1_meanIoU: 0.2566 - out2_loss: 0.3893 - out2_meanIoU: 0.3819 - out3_loss: 0.3903 - out3_meanIoU: 0.3863 - val_loss: 1.9808 - val_out1_loss: 1.1335 - val_out1_meanIoU: 0.2666 - val_out2_loss: 0.4175 - val_out2_meanIoU: 0.3824 - val_out3_loss: 0.4326 - val_out3_meanIoU: 0.3870 - learning_rate: 0.0010
# Epoch 12/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 1.8267 - out1_loss: 1.0904 - out1_meanIoU: 0.2635 - out2_loss: 0.3679 - out2_meanIoU: 0.3953 - out3_loss: 0.3703 - out3_meanIoU: 0.3979 - val_loss: 2.2933 - val_out1_loss: 1.2530 - val_out1_meanIoU: 0.1931 - val_out2_loss: 0.5280 - val_out2_meanIoU: 0.2754 - val_out3_loss: 0.5137 - val_out3_meanIoU: 0.2708 - learning_rate: 0.0010
# Epoch 13/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 1.8951 - out1_loss: 1.1120 - out1_meanIoU: 0.2546 - out2_loss: 0.3898 - out2_meanIoU: 0.3738 - out3_loss: 0.3933 - out3_meanIoU: 0.3785 - val_loss: 5.0298 - val_out1_loss: 2.0385 - val_out1_meanIoU: 0.1357 - val_out2_loss: 1.4462 - val_out2_meanIoU: 0.1440 - val_out3_loss: 1.5512 - val_out3_meanIoU: 0.1283 - learning_rate: 0.0010
# Epoch 14/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 1.8288 - out1_loss: 1.0874 - out1_meanIoU: 0.2636 - out2_loss: 0.3704 - out2_meanIoU: 0.3879 - out3_loss: 0.3713 - out3_meanIoU: 0.3948 - val_loss: 3.2733 - val_out1_loss: 1.5830 - val_out1_meanIoU: 0.1548 - val_out2_loss: 0.8102 - val_out2_meanIoU: 0.1843 - val_out3_loss: 0.8892 - val_out3_meanIoU: 0.1592 - learning_rate: 0.0010
# Epoch 15/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 1.8400 - out1_loss: 1.0944 - out1_meanIoU: 0.2616 - out2_loss: 0.3755 - out2_meanIoU: 0.3874 - out3_loss: 0.3699 - out3_meanIoU: 0.3917 - val_loss: 3.3683 - val_out1_loss: 1.6146 - val_out1_meanIoU: 0.2016 - val_out2_loss: 0.8913 - val_out2_meanIoU: 0.2592 - val_out3_loss: 0.8738 - val_out3_meanIoU: 0.2485 - learning_rate: 0.0010
# Epoch 16/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 1.7249 - out1_loss: 1.0470 - out1_meanIoU: 0.2709 - out2_loss: 0.3394 - out2_meanIoU: 0.4076 - out3_loss: 0.3390 - out3_meanIoU: 0.4133 - val_loss: 2.0524 - val_out1_loss: 1.1614 - val_out1_meanIoU: 0.2475 - val_out2_loss: 0.4538 - val_out2_meanIoU: 0.3525 - val_out3_loss: 0.4415 - val_out3_meanIoU: 0.3560 - learning_rate: 0.0010
# Epoch 17/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 1.6733 - out1_loss: 1.0295 - out1_meanIoU: 0.2796 - out2_loss: 0.3213 - out2_meanIoU: 0.4257 - out3_loss: 0.3232 - out3_meanIoU: 0.4317 - val_loss: 1.8375 - val_out1_loss: 1.0851 - val_out1_meanIoU: 0.2698 - val_out2_loss: 0.3755 - val_out2_meanIoU: 0.4120 - val_out3_loss: 0.3809 - val_out3_meanIoU: 0.4093 - learning_rate: 1.0000e-04
# Epoch 18/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 1.
- learning_rate: 1.0000e-04
# Epoch 34/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 1.4532 - out1_loss: 0.9532 - out1_meanIoU: 0.2990 - out2_loss: 0.2476 - out2_meanIoU: 0.4718 - out3_loss: 0.2520 - out3_meanIoU: 0.4744 - val_loss: 1.6569 - val_out1_loss: 1.0284 - val_out1_meanIoU: 0.2925 - val_out2_loss: 0.3174 - val_out2_meanIoU: 0.4496 - val_out3_loss: 0.3144 - val_out3_meanIoU: 0.4515 - learning_rate: 1.0000e-04
# Epoch 35/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 1.4520 - out1_loss: 0.9494 - out1_meanIoU: 0.3012 - out2_loss: 0.2482 - out2_meanIoU: 0.4706 - out3_loss: 0.2542 - out3_meanIoU: 0.4708 - val_loss: 1.5351 - val_out1_loss: 0.9865 - val_out1_meanIoU: 0.3009 - val_out2_loss: 0.2743 - val_out2_meanIoU: 0.4783 - val_out3_loss: 0.2775 - val_out3_meanIoU: 0.4787 - learning_rate: 1.0000e-04
# Epoch 36/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 1.4271 - out1_loss: 0.9439 - out1_meanIoU: 0.3004 - out2_loss: 0.2393 - out2_meanIoU: 0.4729 - out3_loss: 0.2435 - out3_meanIoU: 0.4728 - val_loss: 1.5506 - val_out1_loss: 0.9916 - val_out1_meanIoU: 0.3006 - val_out2_loss: 0.2804 - val_out2_meanIoU: 0.4761 - val_out3_loss: 0.2814 - val_out3_meanIoU: 0.4786 - learning_rate: 1.0000e-04
# Epoch 37/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 1.4303 - out1_loss: 0.9466 - out1_meanIoU: 0.2995 - out2_loss: 0.2404 - out2_meanIoU: 0.4739 - out3_loss: 0.2439 - out3_meanIoU: 0.4743 - val_loss: 1.5258 - val_out1_loss: 0.9824 - val_out1_meanIoU: 0.2959 - val_out2_loss: 0.2713 - val_out2_meanIoU: 0.4697 - val_out3_loss: 0.2749 - val_out3_meanIoU: 0.4718 - learning_rate: 1.0000e-04
# Epoch 38/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 1.3887 - out1_loss: 0.9311 - out1_meanIoU: 0.3061 - out2_loss: 0.2264 - out2_meanIoU: 0.4889 - out3_loss: 0.2309 - out3_meanIoU: 0.4892 - val_loss: 1.5155 - val_out1_loss: 0.9785 - val_out1_meanIoU: 0.2983 - val_out2_loss: 0.2677 - val_out2_meanIoU: 0.4749 - val_out3_loss: 0.2718 - val_out3_meanIoU: 0.4765 - learning_rate: 1.0000e-05
# Epoch 39/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 1.3839 - out1_loss: 0.9287 - out1_meanIoU: 0.3037 - out2_loss: 0.2248 - out2_meanIoU: 0.4843 - out3_loss: 0.2303 - out3_meanIoU: 0.4833 - val_loss: 1.5088 - val_out1_loss: 0.9759 - val_out1_meanIoU: 0.3004 - val_out2_loss: 0.2659 - val_out2_meanIoU: 0.4786 - val_out3_loss: 0.2694 - val_out3_meanIoU: 0.4803 - learning_rate: 1.0000e-05
# Epoch 40/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 1.3868 - out1_loss: 0.9287 - out1_meanIoU: 0.3049 - out2_loss: 0.2270 - out2_meanIoU: 0.4850 - out3_loss: 0.2317 - out3_meanIoU: 0.4862 - val_loss: 1.5071 - val_out1_loss: 0.9756 - val_out1_meanIoU: 0.2999 - val_out2_loss: 0.2653 - val_out2_meanIoU: 0.4777 - val_out3_loss: 0.2685 - val_out3_meanIoU: 0.4796 - learning_rate: 1.0000e-05
# Epoch 41/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 1.3727 - out1_loss: 0.9249 - out1_meanIoU: 0.3052 - out2_loss: 0.2225 - out2_meanIoU: 0.4863 - out3_loss: 0.2270 - out3_meanIoU: 0.4869 - val_loss: 1.5072 - val_out1_loss: 0.9756 - val_out1_meanIoU: 0.2999 - val_out2_loss: 0.2657 - val_out2_meanIoU: 0.4773 - val_out3_loss: 0.2682 - val_out3_meanIoU: 0.4793 - learning_rate: 1.0000e-05
# Epoch 42/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 1.3972 - out1_loss: 0.9321 - out1_meanIoU: 0.3035 - out2_loss: 0.2301 - out2_meanIoU: 0.4812 - out3_loss: 0.2351 - out3_meanIoU: 0.4813 - val_loss: 1.5065 - val_out1_loss: 0.9756 - val_out1_meanIoU: 0.2996 - val_out2_loss: 0.2653 - val_out2_meanIoU: 0.4770 - val_out3_loss: 0.2677 - val_out3_meanIoU: 0.4789 - learning_rate: 1.0000e-05
# Epoch 43/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 1.4034 - out1_loss: 0.9344 - out1_meanIoU: 0.3022 - out2_loss: 0.2312 - out2_meanIoU: 0.4788 - out3_loss: 0.2375 - out3_meanIoU: 0.4790 - val_loss: 1.5067 - val_out1_loss: 0.9756 - val_out1_meanIoU: 0.2988 - val_out2_loss: 0.2655 - val_out2_meanIoU: 0.4758 - val_out3_loss: 0.2676 - val_out3_meanIoU: 0.4778 - learning_rate: 1.0000e-05
# Epoch 44/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 1.3653 - out1_loss: 0.9216 - out1_meanIoU: 0.3075 - out2_loss: 0.2193 - out2_meanIoU: 0.4913 - out3_loss: 0.2248 - out3_meanIoU: 0.4901 - val_loss: 1.5059 - val_out1_loss: 0.9754 - val_out1_meanIoU: 0.2990 - val_out2_loss: 0.2654 - val_out2_meanIoU: 0.4761 - val_out3_loss: 0.2673 - val_out3_meanIoU: 0.4781 - learning_rate: 1.0000e-05
# Epoch 45/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 1.3824 - out1_loss: 0.9261 - out1_meanIoU: 0.3068 - out2_loss: 0.2256 - out2_meanIoU: 0.4866 - out3_loss: 0.2306 - out3_meanIoU: 0.4876 - val_loss: 1.5071 - val_out1_loss: 0.9759 - val_out1_meanIoU: 0.2983 - val_out2_loss: 0.2658 - val_out2_meanIoU: 0.4749 - val_out3_loss: 0.2676 - val_out3_meanIoU: 0.4771 - learning_rate: 1.0000e-06
# Epoch 46/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 1.3834 - out1_loss: 0.9287 - out1_meanIoU: 0.3041 - out2_loss: 0.2252 - out2_meanIoU: 0.4838 - out3_loss: 0.2304 - out3_meanIoU: 0.4838 - val_loss: 1.5073 - val_out1_loss: 0.9761 - val_out1_meanIoU: 0.2976 - val_out2_loss: 0.2659 - val_out2_meanIoU: 0.4738 - val_out3_loss: 0.2676 - val_out3_meanIoU: 0.4762 - learning_rate: 1.0000e-06
# Epoch 47/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 1.3900 - out1_loss: 0.9299 - out1_meanIoU: 0.3051 - out2_loss: 0.2277 - out2_meanIoU: 0.4844 - out3_loss: 0.2330 - out3_meanIoU: 0.4850 - val_loss: 1.5081 - val_out1_loss: 0.9764 - val_out1_meanIoU: 0.2972 - val_out2_loss: 0.2662 - val_out2_meanIoU: 0.4729 - val_out3_loss: 0.2677 - val_out3_meanIoU: 0.4756 - learning_rate: 1.0000e-06
# Epoch 48/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 1.3800 - out1_loss: 0.9274 - out1_meanIoU: 0.3073 - out2_loss: 0.2242 - out2_meanIoU: 0.4896 - out3_loss: 0.2288 - out3_meanIoU: 0.4898 - val_loss: 1.5079 - val_out1_loss: 0.9764 - val_out1_meanIoU: 0.2971 - val_out2_loss: 0.2661 - val_out2_meanIoU: 0.4727 - val_out3_loss: 0.2676 - val_out3_meanIoU: 0.4752 - learning_rate: 1.0000e-06
# Epoch 49/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 1.3700 - out1_loss: 0.9231 - out1_meanIoU: 0.3071 - out2_loss: 0.2210 - out2_meanIoU: 0.4890 - out3_loss: 0.2259 - out3_meanIoU: 0.4884 - val_loss: 1.5080 - val_out1_loss: 0.9764 - val_out1_meanIoU: 0.2969 - val_out2_loss: 0.2662 - val_out2_meanIoU: 0.4723 - val_out3_loss: 0.2676 - val_out3_meanIoU: 0.4750 - learning_rate: 1.0000e-06

# %%
# Plot and display training and validation loss
plt.figure(figsize=(18, 3))
plt.plot(history['loss'], label='Training', alpha=0.8, color='#ff7f0e', linewidth=2)
plt.plot(history['val_loss'], label='val_tot', alpha=0.9, color='#5a9aa5', linewidth=2)
plt.plot(history['val_out1_loss'], label='out1', alpha=0.9, color='#5f0a3a', linewidth=2)
plt.plot(history['val_out2_loss'], label='out2', alpha=0.9, color='#0a9a85', linewidth=2)
plt.plot(history['val_out3_loss'], label='out3', alpha=0.9, color='#5a9a0f', linewidth=2)
plt.xlim(5, len(history['val_out1_loss']))
plt.ylim(0, 3)
plt.title('Cross Entropy')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# Plot and display training and validation accuracy
plt.figure(figsize=(18, 3))
plt.plot(history['out1_meanIoU'], label='out1_Training', alpha=0.8, color='#ff7f0e', linewidth=2)
plt.plot(history['out2_meanIoU'], label='out2_Training', alpha=0.8, color='#0f7f0e', linewidth=2)
plt.plot(history['out3_meanIoU'], label='out3_Training', alpha=0.8, color='#f00f0e', linewidth=2)
plt.plot(history['val_out1_meanIoU'], label='out1', alpha=0.9, color='#ff00a5', linewidth=2)
plt.plot(history['val_out2_meanIoU'], label='out2', alpha=0.9, color='#0a9a85', linewidth=2)
plt.plot(history['val_out3_meanIoU'], label='out3', alpha=0.9, color='#5a9a0f', linewidth=2)
plt.title('Mean IoU')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ## Test Prediction and Final Evaluation

# %%
X = data['images']
y = data['labels']
y = tfk.utils.to_categorical(y, num_classes=NUM_CLASSES)

# Split the dataset into training and validation (test is given)
train_img, test_img_local, train_lbl, test_lbl_local = train_test_split(X, y, test_size=0.2, random_state=seed)
train_img, val_img, train_lbl, val_lbl = train_test_split(train_img, train_lbl, test_size=0.2, random_state=seed)
test_lbl_local = np.argmax(test_lbl_local, axis=-1)

# %%
# Predict class probabilities and get predicted classes
test_predictions = np.array(model.predict(test_img_local, verbose=0))[2]
test_predictions = np.argmax(test_predictions, axis=-1)
assert test_predictions.shape == test_lbl_local.shape

# %%
# Calculate and display test set accuracy
test_accuracy = accuracy_score(test_lbl_local.flatten(), test_predictions.flatten())
print(f'Accuracy score over the test set: {round(test_accuracy, 4)}')

# Calculate and display test set precision
test_precision = precision_score(test_lbl_local.flatten(), test_predictions.flatten(), average='weighted', zero_division=0)
print(f'Precision score over the test set: {round(test_precision, 4)}')

# Calculate and display test set recall
test_recall = recall_score(test_lbl_local.flatten(), test_predictions.flatten(), average='weighted')
print(f'Recall score over the test set: {round(test_recall, 4)}')

# Calculate and display test set F1 score
test_f1 = f1_score(test_lbl_local.flatten(), test_predictions.flatten(), average='weighted')
print(f'F1 score over the test set: {round(test_f1, 4)}')

# Calculate and display test set mean Intersection Over Union score
# one_hot_pred = tfk.utils.to_categorical(test_predictions, num_classes=NUM_CLASSES)
test_miou = MeanIoU(NUM_CLASSES)
test_miou.update_state(test_lbl_local, test_predictions)
test_miou = test_miou.result().numpy()
print(f'Mean Intersection over Union over the test set: {round(test_miou, 4)}')
# Out:
# Accuracy score over the test set: 0.7673
# Precision score over the test set: 0.7598
# Recall score over the test set: 0.7673
# F1 score over the test set: 0.7552
# Mean Intersection over Union over the test set: 0.48899999260902405

# %% [markdown]
# ## Save

# %%
# Save the model
from datetime import datetime
current_time = datetime.now().strftime("%d|%m-%H:%M")
model_filename = f'UNet_{current_time}.keras'
print("Saved as :",model_filename)
model.save(f'models/{model_filename}', include_optimizer=False)
# Out:
# Saved as : UNet_14|12-16:23.keras

# %% [markdown]
# ## Submission

# %%
# Predict the masks for the submission
preds = model.predict(test_img)
preds = np.argmax(preds, axis=-1)
# Out:
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
# Converts segmentation predictions into a DataFrame format for Kaggle
def y_to_df(y) -> pd.DataFrame:
    n_samples = len(y)
    y_flat = y.reshape(n_samples, -1)
    df = pd.DataFrame(y_flat)
    df["id"] = np.arange(n_samples)
    cols = ["id"] + [col for col in df.columns if col != "id"]
    return df[cols]

# %%
# Create and download the csv submission file
timestep_str = model_filename.replace("model_", "").replace(".keras", "")
submission_filename = f"submissions/submission_{timestep_str}.csv"
submission_df = y_to_df(preds)
submission_df.to_csv(submission_filename, index=False)
