# %% [markdown]
# # Deeper U-net

# %% [markdown]
# ## Description
#
# **Kaggle mean Intersection over Union** : 0.44
#
# **Local test mean Intersection over Union**: 0.46
#
# **Description**: Modification of the baseline U-net with more layers and Weighted Dice as loss function
#
# **Motivation**: Try to improve the performance

# %% [markdown]
# ## Google Drive - Connecting to the project

# %%
from google.colab import drive
import sys
drive.mount('/content/drive')
project_path = "/content/drive/MyDrive/Colab Notebooks/ANN/le acque del friuli - Homework 2"
# %cd {project_path}
sys.path.append(project_path)
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1CRSDpvo8yN6Wc7UchdjWSs6h8RroV7e4/le acque del friuli - Homework 2

# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2

# Set seed for reproducibility
seed = 42

# Import necessary libraries
import os

# Import necessary modules
import logging
import random
import numpy as np
import pandas as pd

# Set seeds for random number generators in NumPy and Python
np.random.seed(seed)
random.seed(seed)

# Import TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl

# Set seed for TensorFlow
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# Import other libraries
import os
import math
from PIL import Image
from keras import backend as K
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline

from datetime import datetime
from tensorflow.keras.metrics import MeanIoU

# %% [markdown]
# ## Parameters

# %%
# Set batch size for training
BATCH_SIZE = 64

# Set learning rate for the optimiser
LEARNING_RATE = 1e-3

# Set early stopping patience threshold
PATIENCE = 10

# Set maximum number of training epochs
EPOCHS = 1000

# Number of classes
NUM_CLASSES = 5

# %% [markdown]
# ## Load Data

# %%
# Load the dataset
data = np.load("dataset/cleaned_dataset.npz")
test_img = data['test_set']

# Split the dataset in images and labels array
X = data['images']
y = data['labels']
y = tfk.utils.to_categorical(y, num_classes=NUM_CLASSES)

# Split the dataset into training, test, and validation
train_img, test_img_local, train_lbl, test_lbl_local = train_test_split(X, y, test_size=0.2, random_state=seed)
train_img, val_img, train_lbl, val_lbl = train_test_split(train_img, train_lbl, test_size=0.2, random_state=seed)

# %%
# Function to create a dataset with batch and shuffle
def make_dataset(images, labels, batch_size, shuffle=True, augment=False, seed=None):
    dataset = tf.data.Dataset.from_tensor_slices((images, labels))

    # Shuffle the dataset if requested
    if shuffle:
        dataset = dataset.shuffle(buffer_size=batch_size * 2, seed=seed)

    # Batch the data
    dataset = dataset.batch(batch_size, drop_remainder=False)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)

    return dataset

# %%
# Create the training dataset
train_dataset = make_dataset(train_img, train_lbl, batch_size=BATCH_SIZE, shuffle=True, augment=True, seed=seed)

# Create the validation dataset
val_dataset = make_dataset(val_img, val_lbl, batch_size=BATCH_SIZE, shuffle=False, augment=False, seed=seed)

# %% [markdown]
# ## Model Implementation

# %%
# Definition of a U-net block
def unet_block(input_tensor, filters, kernel_size=3, activation='relu', stack=2, name=''):
    # Initialise the input tensor
    x = input_tensor

    # Apply a sequence of Conv2D, Batch Normalisation, and Activation layers for the specified number of stacks
    for i in range(stack):
        x = tfkl.Conv2D(filters, kernel_size=kernel_size, padding='same', name=name + 'conv' + str(i + 1))(x)
        x = tfkl.BatchNormalization(name=name + 'bn' + str(i + 1))(x)
        x = tfkl.Activation(activation, name=name + 'activation' + str(i + 1))(x)

    return x

# %%
# Definition of the model
def get_unet_model(input_shape=(64, 128, 1), num_classes=NUM_CLASSES, seed=seed):
    tf.random.set_seed(seed)
    input_layer = tfkl.Input(shape=input_shape, name='input_layer')

    # Downsampling path
    down_block_1 = unet_block(input_layer, 32, name='down_block1_')
    d1 = tfkl.MaxPooling2D()(down_block_1)

    down_block_2 = unet_block(d1, 64, name='down_block2_')
    d2 = tfkl.MaxPooling2D()(down_block_2)

    down_block_3 = unet_block(d2, 128, name='down_block3_')
    d3 = tfkl.MaxPooling2D()(down_block_3)

    # Bottleneck
    bottleneck = unet_block(d3, 256, name='bottleneck')

    # Upsampling path
    u1 = tfkl.UpSampling2D()(bottleneck)
    u1 = tfkl.Concatenate()([u1, down_block_3])
    u1 = unet_block(u1, 128, name='up_block1_')

    u2 = tfkl.UpSampling2D()(u1)
    u2 = tfkl.Concatenate()([u2, down_block_2])
    u2 = unet_block(u2, 64, name='up_block2_')

    u3 = tfkl.UpSampling2D()(u2)
    u3 = tfkl.Concatenate()([u3, down_block_1])
    u3 = unet_block(u3, 32, name='up_block3_')

    # Output Layer
    output_layer = tfkl.Conv2D(num_classes, kernel_size=1, padding='same', activation="softmax", name='output_layer')(u3)

    model = tf.keras.Model(inputs=input_layer, outputs=output_layer, name='UNet')
    return model

# %%
# Model contruction
model = get_unet_model()

# Print a detailed summary of the model
model.summary(expand_nested=False, show_trainable=True)
# Out:
# Model: "UNet"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)           ┃ Output Shape         ┃      Param # ┃ Connected to        ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ input_layer            │ (None, 64, 128, 1)   │            0 │ -                   │    -    │
# │ (InputLayer)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_conv1      │ (None, 64, 128, 32)  │          320 │ input_layer[0][0]   │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_bn1        │ (None, 64, 128, 32)  │          128 │ down_block1_conv1[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_activatio… │ (None, 64, 128, 32)  │            0 │ down_block1_bn1[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_conv2      │ (None, 64, 128, 32)  │        9,248 │ down_block1_activa… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_bn2        │ (None, 64, 128, 32)  │          128 │ down_block1_conv2[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_activatio… │ (None, 64, 128, 32)  │            0 │ down_block1_bn2[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ max_pooling2d          │ (None, 32, 64, 32)   │            0 │ down_block1_activa… │    -    │
# │ (MaxPooling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_conv1      │ (None, 32, 64, 64)   │       18,496 │ max_pooling2d[0][0] │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_bn1        │ (None, 32, 64, 64)   │          256 │ down_block2_conv1[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_activatio… │ (None, 32, 64, 64)   │            0 │ down_block2_bn1[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_conv2      │ (None, 32, 64, 64)   │       36,928 │ down_block2_activa… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_bn2        │ (None, 32, 64, 64)   │          256 │ down_block2_conv2[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_activatio… │ (None, 32, 64, 64)   │            0 │ down_block2_bn2[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ max_pooling2d_1        │ (None, 16, 32, 64)   │            0 │ down_block2_activa… │    -    │
# │ (MaxPooling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block3_conv1      │ (None, 16, 32, 128)  │       73,856 │ max_pooling2d_1[0]… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block3_bn1        │ (None, 16, 32, 128)  │          512 │ down_block3_conv1[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block3_activatio… │ (None, 16, 32, 128)  │            0 │ down_block3_bn1[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block3_conv2      │ (None, 16, 32, 128)  │      147,584 │ down_block3_activa… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block3_bn2        │ (None, 16, 32, 128)  │          512 │ down_block3_conv2[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block3_activatio… │ (None, 16, 32, 128)  │            0 │ down_block3_bn2[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ max_pooling2d_2        │ (None, 8, 16, 128)   │            0 │ down_block3_activa… │    -    │
# │ (MaxPooling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckconv1        │ (None, 8, 16, 256)   │      295,168 │ max_pooling2d_2[0]… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckbn1          │ (None, 8, 16, 256)   │        1,024 │ bottleneckconv1[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckactivation1  │ (None, 8, 16, 256)   │            0 │ bottleneckbn1[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckconv2        │ (None, 8, 16, 256)   │      590,080 │ bottleneckactivati… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckbn2          │ (None, 8, 16, 256)   │        1,024 │ bottleneckconv2[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckactivation2  │ (None, 8, 16, 256)   │            0 │ bottleneckbn2[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_sampling2d          │ (None, 16, 32, 256)  │            0 │ bottleneckactivati… │    -    │
# │ (UpSampling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ concatenate            │ (None, 16, 32, 384)  │            0 │ up_sampling2d[0][0… │    -    │
# │ (Concatenate)          │                      │              │ down_block3_activa… │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_conv1        │ (None, 16, 32, 128)  │      442,496 │ concatenate[0][0]   │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_bn1          │ (None, 16, 32, 128)  │          512 │ up_block1_conv1[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_activation1  │ (None, 16, 32, 128)  │            0 │ up_block1_bn1[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_conv2        │ (None, 16, 32, 128)  │      147,584 │ up_block1_activati… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_bn2          │ (None, 16, 32, 128)  │          512 │ up_block1_conv2[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_activation2  │ (None, 16, 32, 128)  │            0 │ up_block1_bn2[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_sampling2d_1        │ (None, 32, 64, 128)  │            0 │ up_block1_activati… │    -    │
# │ (UpSampling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ concatenate_1          │ (None, 32, 64, 192)  │            0 │ up_sampling2d_1[0]… │    -    │
# │ (Concatenate)          │                      │              │ down_block2_activa… │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_conv1        │ (None, 32, 64, 64)   │      110,656 │ concatenate_1[0][0] │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_bn1          │ (None, 32, 64, 64)   │          256 │ up_block2_conv1[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_activation1  │ (None, 32, 64, 64)   │            0 │ up_block2_bn1[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_conv2        │ (None, 32, 64, 64)   │       36,928 │ up_block2_activati… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_bn2          │ (None, 32, 64, 64)   │          256 │ up_block2_conv2[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_activation2  │ (None, 32, 64, 64)   │            0 │ up_block2_bn2[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_sampling2d_2        │ (None, 64, 128, 64)  │            0 │ up_block2_activati… │    -    │
# │ (UpSampling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ concatenate_2          │ (None, 64, 128, 96)  │            0 │ up_sampling2d_2[0]… │    -    │
# │ (Concatenate)          │                      │              │ down_block1_activa… │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block3_conv1        │ (None, 64, 128, 32)  │       27,680 │ concatenate_2[0][0] │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block3_bn1          │ (None, 64, 128, 32)  │          128 │ up_block3_conv1[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block3_activation1  │ (None, 64, 128, 32)  │            0 │ up_block3_bn1[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block3_conv2        │ (None, 64, 128, 32)  │        9,248 │ up_block3_activati… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block3_bn2          │ (None, 64, 128, 32)  │          128 │ up_block3_conv2[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block3_activation2  │ (None, 64, 128, 32)  │            0 │ up_block3_bn2[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ output_layer (Conv2D)  │ (None, 64, 128, 5)   │          165 │ up_block3_activati… │    Y    │
# └────────────────────────┴──────────────────────┴──────────────┴─────────────────────┴─────────┘
#  Total params: 1,952,069 (7.45 MB)
#  Trainable params: 1,949,253 (7.44 MB)
#  Non-trainable params: 2,816 (11.00 KB)

# %% [markdown]
# ## Training

# %%
# Model compilation with Adam as optimizer and Dice as loss function
model.compile(
    loss=tfk.losses.Dice(),
    optimizer=tf.keras.optimizers.Adam(LEARNING_RATE),
    metrics=["accuracy",tfk.metrics.OneHotMeanIoU(NUM_CLASSES,ignore_class=0)]
)

# %%
# Implementation of early stopping as a technique to avoid overfitting
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=PATIENCE,
    restore_best_weights=True
)

# %%
# Actual training of the model with the given parameters
history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=val_dataset,
    callbacks=[early_stopping],
    verbose=1,
).history
# Out:
# Epoch 1/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - accuracy: 0.4245 - loss: 0.6309 - one_hot_mean_io_u: 0.1910 - val_accuracy: 0.2501 - val_loss: 0.7609 - val_one_hot_mean_io_u: 0.0283
# Epoch 2/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.6107 - loss: 0.4189 - one_hot_mean_io_u: 0.3147 - val_accuracy: 0.3284 - val_loss: 0.6902 - val_one_hot_mean_io_u: 0.1313
# Epoch 3/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.6070 - loss: 0.4090 - one_hot_mean_io_u: 0.3015 - val_accuracy: 0.4854 - val_loss: 0.5357 - val_one_hot_mean_io_u: 0.2302
# Epoch 4/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - accuracy: 0.6311 - loss: 0.3794 - one_hot_mean_io_u: 0.3284 - val_accuracy: 0.4696 - val_loss: 0.5392 - val_one_hot_mean_io_u: 0.2340
# Epoch 5/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - accuracy: 0.6570 - loss: 0.3504 - one_hot_mean_io_u: 0.3498 - val_accuracy: 0.5023 - val_loss: 0.5056 - val_one_hot_mean_io_u: 0.2069
# Epoch 6/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.6457 - loss: 0.3595 - one_hot_mean_io_u: 0.3401 - val_accuracy: 0.2373 - val_loss: 0.7636 - val_one_hot_mean_io_u: 8.0954e-04
# Epoch 7/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.6488 - loss: 0.3553 - one_hot_mean_io_u: 0.3500 - val_accuracy: 0.4624 - val_loss: 0.5394 - val_one_hot_mean_io_u: 0.1908
# Epoch 8/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - accuracy: 0.6664 - loss: 0.3371 - one_hot_mean_io_u: 0.3656 - val_accuracy: 0.5074 - val_loss: 0.4963 - val_one_hot_mean_io_u: 0.2472
# Epoch 9/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - accuracy: 0.6957 - loss: 0.3073 - one_hot_mean_io_u: 0.3912 - val_accuracy: 0.3717 - val_loss: 0.6298 - val_one_hot_mean_io_u: 0.1131
# Epoch 10/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - accuracy: 0.6878 - loss: 0.3148 - one_hot_mean_io_u: 0.3801 - val_accuracy: 0.4866 - val_loss: 0.5153 - val_one_hot_mean_io_u: 0.2050
# Epoch 11/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.6932 - loss: 0.3090 - one_hot_mean_io_u: 0.3904 - val_accuracy: 0.4083 - val_loss: 0.5930 - val_one_hot_mean_io_u: 0.1192
# Epoch 12/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - accuracy: 0.6798 - loss: 0.3220 - one_hot_mean_io_u: 0.3760 - val_accuracy: 0.5865 - val_loss: 0.4157 - val_one_hot_mean_io_u: 0.3012
# Epoch 13/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.6808 - loss: 0.3208 - one_hot_mean_io_u: 0.3746 - val_accuracy: 0.4516 - val_loss: 0.5493 - val_one_hot_mean_io_u: 0.1853
# Epoch 14/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - accuracy: 0.7100 - loss: 0.2916 - one_hot_mean_io_u: 0.4036 - val_accuracy: 0.4229 - val_loss: 0.5780 - val_one_hot_mean_io_u: 0.1552
# Epoch 15/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.6969 - loss: 0.3044 - one_hot_mean_io_u: 0.3878 - val_accuracy: 0.2604 - val_loss: 0.7399 - val_one_hot_mean_io_u: 0.0310
# Epoch 16/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - accuracy: 0.7091 - loss: 0.2923 - one_hot_mean_io_u: 0.4069 - val_accuracy: 0.2359 - val_loss: 0.7641 - val_one_hot_mean_io_u: 1.6310e-04
# Epoch 17/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.7130 - loss: 0.2881 - one_hot_mean_io_u: 0.4038 - val_accuracy: 0.5561 - val_loss: 0.4445 - val_one_hot_mean_io_u: 0.2694
# Epoch 18/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - accuracy: 0.7284 - loss: 0.2727 - one_hot_mean_io_u: 0.4141 - val_accuracy: 0.4619 - val_loss: 0.5384 - val_one_hot_mean_io_u: 0.1855
# Epoch 19/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 159ms/step - accuracy: 0.7213 - loss: 0.2798 - one_hot_mean_io_u: 0.4087 - val_accuracy: 0.5001 - val_loss: 0.5006 - val_one_hot_mean_io_u: 0.2438
# Epoch 20/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.7289 - loss: 0.2721 - one_hot_mean_io_u: 0.4104 - val_accuracy: 0.6311 - val_loss: 0.3694 - val_one_hot_mean_io_u: 0.3577
# Epoch 21/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - accuracy: 0.7283 - loss: 0.2726 - one_hot_mean_io_u: 0.4213 - val_accuracy: 0.4376 - val_loss: 0.5635 - val_one_hot_mean_io_u: 0.2065
# Epoch 22/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.7327 - loss: 0.2683 - one_hot_mean_io_u: 0.4187 - val_accuracy: 0.6448 - val_loss: 0.3572 - val_one_hot_mean_io_u: 0.3361
# Epoch 23/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - accuracy: 0.7459 - loss: 0.2550 - one_hot_mean_io_u: 0.4290 - val_accuracy: 0.4936 - val_loss: 0.5069 - val_one_hot_mean_io_u: 0.2029
# Epoch 24/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.7449 - loss: 0.2558 - one_hot_mean_io_u: 0.4276 - val_accuracy: 0.4539 - val_loss: 0.5462 - val_one_hot_mean_io_u: 0.1984
# Epoch 25/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.7287 - loss: 0.2721 - one_hot_mean_io_u: 0.4031 - val_accuracy: 0.5273 - val_loss: 0.4734 - val_one_hot_mean_io_u: 0.2159
# Epoch 26/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - accuracy: 0.7397 - loss: 0.2612 - one_hot_mean_io_u: 0.4195 - val_accuracy: 0.4818 - val_loss: 0.5185 - val_one_hot_mean_io_u: 0.2051
# Epoch 27/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.7519 - loss: 0.2489 - one_hot_mean_io_u: 0.4334 - val_accuracy: 0.7105 - val_loss: 0.2900 - val_one_hot_mean_io_u: 0.4149
# Epoch 28/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.7557 - loss: 0.2450 - one_hot_mean_io_u: 0.4364 - val_accuracy: 0.6629 - val_loss: 0.3375 - val_one_hot_mean_io_u: 0.3632
# Epoch 29/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - accuracy: 0.7608 - loss: 0.2399 - one_hot_mean_io_u: 0.4393 - val_accuracy: 0.5810 - val_loss: 0.4195 - val_one_hot_mean_io_u: 0.3075
# Epoch 30/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.7546 - loss: 0.2460 - one_hot_mean_io_u: 0.4362 - val_accuracy: 0.7414 - val_loss: 0.2594 - val_one_hot_mean_io_u: 0.4320
# Epoch 31/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7462 - loss: 0.2544 - one_hot_mean_io_u: 0.4328 - val_accuracy: 0.7112 - val_loss: 0.2895 - val_one_hot_mean_io_u: 0.4071
# Epoch 32/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - accuracy: 0.7622 - loss: 0.2384 - one_hot_mean_io_u: 0.4432 - val_accuracy: 0.6485 - val_loss: 0.3518 - val_one_hot_mean_io_u: 0.3695
# Epoch 33/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 180ms/step - accuracy: 0.7614 - loss: 0.2392 - one_hot_mean_io_u: 0.4374 - val_accuracy: 0.6455 - val_loss: 0.3549 - val_one_hot_mean_io_u: 0.3424
# Epoch 34/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.7603 - loss: 0.2402 - one_hot_mean_io_u: 0.4398 - val_accuracy: 0.6786 - val_loss: 0.3218 - val_one_hot_mean_io_u: 0.3553
# Epoch 35/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - accuracy: 0.7665 - loss: 0.2340 - one_hot_mean_io_u: 0.4477 - val_accuracy: 0.4970 - val_loss: 0.5033 - val_one_hot_mean_io_u: 0.2144
# Epoch 36/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7632 - loss: 0.2373 - one_hot_mean_io_u: 0.4389 - val_accuracy: 0.7339 - val_loss: 0.2665 - val_one_hot_mean_io_u: 0.4449
# Epoch 37/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - accuracy: 0.7725 - loss: 0.2281 - one_hot_mean_io_u: 0.4506 - val_accuracy: 0.7539 - val_loss: 0.2466 - val_one_hot_mean_io_u: 0.4598
# Epoch 38/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.7742 - loss: 0.2263 - one_hot_mean_io_u: 0.4499 - val_accuracy: 0.7086 - val_loss: 0.2918 - val_one_hot_mean_io_u: 0.3908
# Epoch 39/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.7804 - loss: 0.2201 - one_hot_mean_io_u: 0.4522 - val_accuracy: 0.6801 - val_loss: 0.3202 - val_one_hot_mean_io_u: 0.3583
# Epoch 40/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.7643 - loss: 0.2362 - one_hot_mean_io_u: 0.4440 - val_accuracy: 0.6154 - val_loss: 0.3851 - val_one_hot_mean_io_u: 0.3124
# Epoch 41/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7688 - loss: 0.2318 - one_hot_mean_io_u: 0.4474 - val_accuracy: 0.7140 - val_loss: 0.2864 - val_one_hot_mean_io_u: 0.4018
# Epoch 42/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 164ms/step - accuracy: 0.7802 - loss: 0.2202 - one_hot_mean_io_u: 0.4522 - val_accuracy: 0.6691 - val_loss: 0.3313 - val_one_hot_mean_io_u: 0.3578
# Epoch 43/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - accuracy: 0.7654 - loss: 0.2350 - one_hot_mean_io_u: 0.4412 - val_accuracy: 0.6308 - val_loss: 0.3697 - val_one_hot_mean_io_u: 0.3408
# Epoch 44/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.7733 - loss: 0.2271 - one_hot_mean_io_u: 0.4481 - val_accuracy: 0.6707 - val_loss: 0.3297 - val_one_hot_mean_io_u: 0.3528
# Epoch 45/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7797 - loss: 0.2206 - one_hot_mean_io_u: 0.4550 - val_accuracy: 0.7448 - val_loss: 0.2561 - val_one_hot_mean_io_u: 0.4432
# Epoch 46/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.7771 - loss: 0.2234 - one_hot_mean_io_u: 0.4532 - val_accuracy: 0.7203 - val_loss: 0.2801 - val_one_hot_mean_io_u: 0.4171
# Epoch 47/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.7846 - loss: 0.2158 - one_hot_mean_io_u: 0.4585 - val_accuracy: 0.7364 - val_loss: 0.2641 - val_one_hot_mean_io_u: 0.4260

# %%
# Plot the loss function value over epochs
plt.figure(figsize=(18, 3))
plt.plot(history['loss'], label='Training', alpha=0.8, color='#ff7f0e', linewidth=2)
plt.plot(history['val_loss'], label='Validation', alpha=0.9, color='#5a9aa5', linewidth=2)
plt.title('Dice')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ## Test Prediction and Final Evaluation

# %%
# Predict class probabilities and get predicted classes
test_predictions = model.predict(test_img_local, verbose=0)
test_predictions = np.argmax(test_predictions, axis=-1)
test_lbl_local = np.argmax(test_lbl_local, axis=-1)

# %%
# Calculate and display test set accuracy
test_accuracy = accuracy_score(test_lbl_local.flatten(), test_predictions.flatten())
print(f'Accuracy score over the test set: {round(test_accuracy, 4)}')

# Calculate and display test set precision
test_precision = precision_score(test_lbl_local.flatten(), test_predictions.flatten(), average='weighted', zero_division=0)
print(f'Precision score over the test set: {round(test_precision, 4)}')

# Calculate and display test set recall
test_recall = recall_score(test_lbl_local.flatten(), test_predictions.flatten(), average='weighted')
print(f'Recall score over the test set: {round(test_recall, 4)}')

# Calculate and display test set F1 score
test_f1 = f1_score(test_lbl_local.flatten(), test_predictions.flatten(), average='weighted')
print(f'F1 score over the test set: {round(test_f1, 4)}')

# Calculate and display test set mean Intersection Over Union score
# one_hot_pred = tfk.utils.to_categorical(test_predictions, num_classes=NUM_CLASSES)
test_miou = MeanIoU(NUM_CLASSES)
test_miou.update_state(test_lbl_local, test_predictions)
test_miou = test_miou.result().numpy()
print(f'Mean Intersection over Union over the test set: {round(test_miou, 4)}')
# Out:
# Accuracy score over the test set: 0.7352
# Precision score over the test set: 0.7335
# Recall score over the test set: 0.7352
# F1 score over the test set: 0.728
# Mean Intersection over Union over the test set: 0.459199994802475

# %% [markdown]
# ## Save

# %%
# Save the model
from datetime import datetime
current_time = datetime.now().strftime("%d|%m-%H:%M")
model_filename = f'UNet_{current_time}.keras'
print("Saved as :",model_filename)
model.save(f'models/{model_filename}', include_optimizer=False)
# Out:
# Saved as : UNet_14|12-11:47.keras

# %% [markdown]
# ## Submission

# %%
# Predict the masks for the submission
preds = model.predict(test_img)
preds = np.argmax(preds, axis=-1)
# Out:
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step

# %%
# Converts segmentation predictions into a DataFrame format for Kaggle
def y_to_df(y) -> pd.DataFrame:
    n_samples = len(y)
    y_flat = y.reshape(n_samples, -1)
    df = pd.DataFrame(y_flat)
    df["id"] = np.arange(n_samples)
    cols = ["id"] + [col for col in df.columns if col != "id"]
    return df[cols]

# %%
# Create and download the csv submission file
timestep_str = model_filename.replace("model_", "").replace(".keras", "")
submission_filename = f"submissions/submission_{timestep_str}.csv"
submission_df = y_to_df(preds)
submission_df.to_csv(submission_filename, index=False)
