# %% [markdown]
# # Focal and learning rate scheduling U-net

# %% [markdown]
# ## Description
#
# **Kaggle mean Intersection over Union** : 0.47
#
# **Local test mean Intersection over Union**: 0.48
#
# **Description**: Modification of the baseline U-net with more layers and Focal as loss function and learning rate scheduling.
#
# **Motivation**: Try to improve the performance

# %% [markdown]
# ## Google Drive - Connecting to the project

# %%
from google.colab import drive
import sys
drive.mount('/content/drive')
project_path = "/content/drive/MyDrive/Colab Notebooks/ANN/le acque del friuli - Homework 2"
# %cd {project_path}
sys.path.append(project_path)
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1CRSDpvo8yN6Wc7UchdjWSs6h8RroV7e4/le acque del friuli - Homework 2

# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2

# Set seed for reproducibility
seed = 42

# Import necessary libraries
import os

# Import necessary modules
import logging
import random
import numpy as np
import pandas as pd

# Set seeds for random number generators in NumPy and Python
np.random.seed(seed)
random.seed(seed)

# Import TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl

# Set seed for TensorFlow
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# Import other libraries
import os
import math
from PIL import Image
from keras import backend as K
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline

from datetime import datetime
from tensorflow.keras.metrics import MeanIoU

# %% [markdown]
# ## Parameters

# %%
# Set batch size for training
BATCH_SIZE = 64

# Number of classes
NUM_CLASSES = 5

# Input shape
INPUT_SHAPE = (64,128,1)

# Set learning rate for the optimiser
LEARNING_RATE = 1e-3

# Set early stopping patience threshold
PATIENCE = 10

# Set plateauing patience threshold
LR_PATIENCE = 5

# Set maximum number of training epochs
EPOCHS = 1000

# %% [markdown]
# ## Load Data

# %%
def color_img(image):
    image = (image * 255).astype(np.uint8)
    return cv2.applyColorMap(image, cv2.COLORMAP_RAINBOW) # https://docs.opencv.org/3.4/d3/d50/group__imgproc__colormap.html

# %%
# Load the dataset
data = np.load("dataset/cleaned_dataset.npz")
test_img = data['test_set']

# Split the dataset in images and labels array
X = data['images']
y = data['labels']
y = tfk.utils.to_categorical(y, num_classes=NUM_CLASSES)

# Split the dataset into training, test, and validation
train_img, test_img_local, train_lbl, test_lbl_local = train_test_split(X, y, test_size=0.2, random_state=seed)
train_img, val_img, train_lbl, val_lbl = train_test_split(train_img, train_lbl, test_size=0.2, random_state=seed)

# %%
# Function to create a dataset with batch and shuffle
def make_dataset(images, labels, batch_size, shuffle=True, augment=False, seed=None):
    dataset = tf.data.Dataset.from_tensor_slices((images, labels))

    # Shuffle the dataset if requested
    if shuffle:
        dataset = dataset.shuffle(buffer_size=batch_size * 2, seed=seed)

    # Batch the data
    dataset = dataset.batch(batch_size, drop_remainder=False)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)

    return dataset

# %%
# Create the training dataset
train_dataset = make_dataset(train_img, train_lbl, batch_size=BATCH_SIZE, shuffle=True, augment=True, seed=seed)

# Create the validation dataset
val_dataset = make_dataset(val_img, val_lbl, batch_size=BATCH_SIZE, shuffle=False, augment=False, seed=seed)

# %% [markdown]
# ## Model Implementation

# %%
# Definition of a U-net block
def unet_block(input_tensor, filters, kernel_size=3, activation='relu', stack=2, name=''):
    # Initialise the input tensor
    x = input_tensor

    # Apply a sequence of Conv2D, Batch Normalisation, and Activation layers for the specified number of stacks
    for i in range(stack):
        x = tfkl.Conv2D(filters, kernel_size=kernel_size, padding='same', name=name + 'conv' + str(i + 1))(x)
        x = tfkl.BatchNormalization(name=name + 'bn' + str(i + 1))(x)
        x = tfkl.Activation(activation, name=name + 'activation' + str(i + 1))(x)

    return x

# %%
# Definition of the model
def get_unet_model(input_shape=INPUT_SHAPE, num_classes=NUM_CLASSES, seed=seed):
    tf.random.set_seed(seed)
    input_layer = tfkl.Input(shape=input_shape, name='input_layer')

    # Downsampling path
    down_block_1 = unet_block(input_layer, 32, name='down_block1_')
    d1 = tfkl.MaxPooling2D()(down_block_1)

    down_block_2 = unet_block(d1, 64, name='down_block2_')
    d2 = tfkl.MaxPooling2D()(down_block_2)

    down_block_3 = unet_block(d2, 128, name='down_block3_')
    d3 = tfkl.MaxPooling2D()(down_block_3)

    # Bottleneck
    bottleneck = unet_block(d3, 256, name='bottleneck')

    # Upsampling path
    u1 = tfkl.UpSampling2D()(bottleneck)
    u1 = tfkl.Concatenate()([u1, down_block_3])
    u1 = unet_block(u1, 128, name='up_block1_')

    u2 = tfkl.UpSampling2D()(u1)
    u2 = tfkl.Concatenate()([u2, down_block_2])
    u2 = unet_block(u2, 64, name='up_block2_')

    u3 = tfkl.UpSampling2D()(u2)
    u3 = tfkl.Concatenate()([u3, down_block_1])
    u3 = unet_block(u3, 32, name='up_block3_')

    # Output Layer
    output_layer = tfkl.Conv2D(num_classes, kernel_size=1, padding='same', activation="softmax", name='output_layer')(u3)

    model = tf.keras.Model(inputs=input_layer, outputs=output_layer, name='UNet')
    return model

# %%
# Model contruction
model = get_unet_model()

# Print a detailed summary of the model
model.summary(expand_nested=False, show_trainable=True)
# Out:
# Model: "UNet"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)           ┃ Output Shape         ┃      Param # ┃ Connected to        ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ input_layer            │ (None, 64, 128, 1)   │            0 │ -                   │    -    │
# │ (InputLayer)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_conv1      │ (None, 64, 128, 32)  │          320 │ input_layer[0][0]   │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_bn1        │ (None, 64, 128, 32)  │          128 │ down_block1_conv1[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_activatio… │ (None, 64, 128, 32)  │            0 │ down_block1_bn1[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_conv2      │ (None, 64, 128, 32)  │        9,248 │ down_block1_activa… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_bn2        │ (None, 64, 128, 32)  │          128 │ down_block1_conv2[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block1_activatio… │ (None, 64, 128, 32)  │            0 │ down_block1_bn2[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ max_pooling2d          │ (None, 32, 64, 32)   │            0 │ down_block1_activa… │    -    │
# │ (MaxPooling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_conv1      │ (None, 32, 64, 64)   │       18,496 │ max_pooling2d[0][0] │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_bn1        │ (None, 32, 64, 64)   │          256 │ down_block2_conv1[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_activatio… │ (None, 32, 64, 64)   │            0 │ down_block2_bn1[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_conv2      │ (None, 32, 64, 64)   │       36,928 │ down_block2_activa… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_bn2        │ (None, 32, 64, 64)   │          256 │ down_block2_conv2[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block2_activatio… │ (None, 32, 64, 64)   │            0 │ down_block2_bn2[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ max_pooling2d_1        │ (None, 16, 32, 64)   │            0 │ down_block2_activa… │    -    │
# │ (MaxPooling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block3_conv1      │ (None, 16, 32, 128)  │       73,856 │ max_pooling2d_1[0]… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block3_bn1        │ (None, 16, 32, 128)  │          512 │ down_block3_conv1[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block3_activatio… │ (None, 16, 32, 128)  │            0 │ down_block3_bn1[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block3_conv2      │ (None, 16, 32, 128)  │      147,584 │ down_block3_activa… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block3_bn2        │ (None, 16, 32, 128)  │          512 │ down_block3_conv2[… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ down_block3_activatio… │ (None, 16, 32, 128)  │            0 │ down_block3_bn2[0]… │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ max_pooling2d_2        │ (None, 8, 16, 128)   │            0 │ down_block3_activa… │    -    │
# │ (MaxPooling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckconv1        │ (None, 8, 16, 256)   │      295,168 │ max_pooling2d_2[0]… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckbn1          │ (None, 8, 16, 256)   │        1,024 │ bottleneckconv1[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckactivation1  │ (None, 8, 16, 256)   │            0 │ bottleneckbn1[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckconv2        │ (None, 8, 16, 256)   │      590,080 │ bottleneckactivati… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckbn2          │ (None, 8, 16, 256)   │        1,024 │ bottleneckconv2[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ bottleneckactivation2  │ (None, 8, 16, 256)   │            0 │ bottleneckbn2[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_sampling2d          │ (None, 16, 32, 256)  │            0 │ bottleneckactivati… │    -    │
# │ (UpSampling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ concatenate            │ (None, 16, 32, 384)  │            0 │ up_sampling2d[0][0… │    -    │
# │ (Concatenate)          │                      │              │ down_block3_activa… │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_conv1        │ (None, 16, 32, 128)  │      442,496 │ concatenate[0][0]   │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_bn1          │ (None, 16, 32, 128)  │          512 │ up_block1_conv1[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_activation1  │ (None, 16, 32, 128)  │            0 │ up_block1_bn1[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_conv2        │ (None, 16, 32, 128)  │      147,584 │ up_block1_activati… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_bn2          │ (None, 16, 32, 128)  │          512 │ up_block1_conv2[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block1_activation2  │ (None, 16, 32, 128)  │            0 │ up_block1_bn2[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_sampling2d_1        │ (None, 32, 64, 128)  │            0 │ up_block1_activati… │    -    │
# │ (UpSampling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ concatenate_1          │ (None, 32, 64, 192)  │            0 │ up_sampling2d_1[0]… │    -    │
# │ (Concatenate)          │                      │              │ down_block2_activa… │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_conv1        │ (None, 32, 64, 64)   │      110,656 │ concatenate_1[0][0] │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_bn1          │ (None, 32, 64, 64)   │          256 │ up_block2_conv1[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_activation1  │ (None, 32, 64, 64)   │            0 │ up_block2_bn1[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_conv2        │ (None, 32, 64, 64)   │       36,928 │ up_block2_activati… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_bn2          │ (None, 32, 64, 64)   │          256 │ up_block2_conv2[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block2_activation2  │ (None, 32, 64, 64)   │            0 │ up_block2_bn2[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_sampling2d_2        │ (None, 64, 128, 64)  │            0 │ up_block2_activati… │    -    │
# │ (UpSampling2D)         │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ concatenate_2          │ (None, 64, 128, 96)  │            0 │ up_sampling2d_2[0]… │    -    │
# │ (Concatenate)          │                      │              │ down_block1_activa… │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block3_conv1        │ (None, 64, 128, 32)  │       27,680 │ concatenate_2[0][0] │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block3_bn1          │ (None, 64, 128, 32)  │          128 │ up_block3_conv1[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block3_activation1  │ (None, 64, 128, 32)  │            0 │ up_block3_bn1[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block3_conv2        │ (None, 64, 128, 32)  │        9,248 │ up_block3_activati… │    Y    │
# │ (Conv2D)               │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block3_bn2          │ (None, 64, 128, 32)  │          128 │ up_block3_conv2[0]… │    Y    │
# │ (BatchNormalization)   │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ up_block3_activation2  │ (None, 64, 128, 32)  │            0 │ up_block3_bn2[0][0] │    -    │
# │ (Activation)           │                      │              │                     │         │
# ├────────────────────────┼──────────────────────┼──────────────┼─────────────────────┼─────────┤
# │ output_layer (Conv2D)  │ (None, 64, 128, 5)   │          165 │ up_block3_activati… │    Y    │
# └────────────────────────┴──────────────────────┴──────────────┴─────────────────────┴─────────┘
#  Total params: 1,952,069 (7.45 MB)
#  Trainable params: 1,949,253 (7.44 MB)
#  Non-trainable params: 2,816 (11.00 KB)

# %% [markdown]
# ## Training

# %%
# Model compilation with Adam as optimizer and Categorical Focal Crossentropy as loss function
model.compile(
    loss=tfk.losses.CategoricalFocalCrossentropy(alpha=2),
    optimizer=tf.keras.optimizers.Adam(LEARNING_RATE),
    metrics=[tfk.metrics.OneHotMeanIoU(NUM_CLASSES,ignore_class=0, name='meanIoU')]
)

# %%
# Implementation of early stopping as a technique to avoid overfitting
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_meanIoU',
    mode='max',
    patience=PATIENCE,
    restore_best_weights=True
)

# Implementation of reduce on plateau
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_meanIoU',
    mode='max',
    factor=0.1,
    patience=LR_PATIENCE,
    min_lr=1e-5
)

callbacks = [early_stopping, reduce_lr]

# %%
# Actual training of the model with the given parameters
history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=val_dataset,
    callbacks=callbacks,
    verbose=1,
).history
# Out:
# Epoch 1/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 44s 817ms/step - loss: 1.7200 - meanIoU: 0.1733 - val_loss: 24.0903 - val_meanIoU: 9.5455e-05 - learning_rate: 0.0010
# Epoch 2/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 1.1561 - meanIoU: 0.2671 - val_loss: 17.1269 - val_meanIoU: 0.0176 - learning_rate: 0.0010
# Epoch 3/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 1.0096 - meanIoU: 0.3132 - val_loss: 7.9315 - val_meanIoU: 0.0906 - learning_rate: 0.0010
# Epoch 4/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.9166 - meanIoU: 0.3401 - val_loss: 3.7011 - val_meanIoU: 0.1011 - learning_rate: 0.0010
# Epoch 5/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.8884 - meanIoU: 0.3508 - val_loss: 1.8585 - val_meanIoU: 0.1945 - learning_rate: 0.0010
# Epoch 6/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.8508 - meanIoU: 0.3632 - val_loss: 1.5140 - val_meanIoU: 0.1848 - learning_rate: 0.0010
# Epoch 7/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.8753 - meanIoU: 0.3540 - val_loss: 1.1014 - val_meanIoU: 0.3138 - learning_rate: 0.0010
# Epoch 8/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.7852 - meanIoU: 0.3876 - val_loss: 1.2072 - val_meanIoU: 0.3011 - learning_rate: 0.0010
# Epoch 9/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.7609 - meanIoU: 0.4006 - val_loss: 1.0248 - val_meanIoU: 0.3042 - learning_rate: 0.0010
# Epoch 10/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.7074 - meanIoU: 0.4028 - val_loss: 3.1740 - val_meanIoU: 0.1651 - learning_rate: 0.0010
# Epoch 11/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.6914 - meanIoU: 0.4133 - val_loss: 1.8333 - val_meanIoU: 0.1549 - learning_rate: 0.0010
# Epoch 12/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.6955 - meanIoU: 0.4004 - val_loss: 1.4571 - val_meanIoU: 0.2256 - learning_rate: 0.0010
# Epoch 13/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.6443 - meanIoU: 0.4285 - val_loss: 0.8547 - val_meanIoU: 0.3711 - learning_rate: 1.0000e-04
# Epoch 14/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.5948 - meanIoU: 0.4385 - val_loss: 0.7711 - val_meanIoU: 0.3992 - learning_rate: 1.0000e-04
# Epoch 15/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.5815 - meanIoU: 0.4360 - val_loss: 0.7180 - val_meanIoU: 0.4153 - learning_rate: 1.0000e-04
# Epoch 16/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.5524 - meanIoU: 0.4588 - val_loss: 0.6864 - val_meanIoU: 0.4274 - learning_rate: 1.0000e-04
# Epoch 17/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.5520 - meanIoU: 0.4461 - val_loss: 0.6491 - val_meanIoU: 0.4397 - learning_rate: 1.0000e-04
# Epoch 18/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.5516 - meanIoU: 0.4474 - val_loss: 0.6285 - val_meanIoU: 0.4441 - learning_rate: 1.0000e-04
# Epoch 19/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.5579 - meanIoU: 0.4426 - val_loss: 0.6258 - val_meanIoU: 0.4467 - learning_rate: 1.0000e-04
# Epoch 20/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.5603 - meanIoU: 0.4428 - val_loss: 0.6292 - val_meanIoU: 0.4413 - learning_rate: 1.0000e-04
# Epoch 21/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.5341 - meanIoU: 0.4568 - val_loss: 0.6237 - val_meanIoU: 0.4442 - learning_rate: 1.0000e-04
# Epoch 22/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.5345 - meanIoU: 0.4482 - val_loss: 0.6176 - val_meanIoU: 0.4502 - learning_rate: 1.0000e-04
# Epoch 23/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.5160 - meanIoU: 0.4542 - val_loss: 0.6196 - val_meanIoU: 0.4485 - learning_rate: 1.0000e-04
# Epoch 24/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.5158 - meanIoU: 0.4554 - val_loss: 0.6193 - val_meanIoU: 0.4428 - learning_rate: 1.0000e-04
# Epoch 25/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.5052 - meanIoU: 0.4584 - val_loss: 0.6050 - val_meanIoU: 0.4522 - learning_rate: 1.0000e-04
# Epoch 26/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.4922 - meanIoU: 0.4613 - val_loss: 0.6063 - val_meanIoU: 0.4505 - learning_rate: 1.0000e-04
# Epoch 27/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.5031 - meanIoU: 0.4595 - val_loss: 0.6006 - val_meanIoU: 0.4528 - learning_rate: 1.0000e-04
# Epoch 28/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.4965 - meanIoU: 0.4596 - val_loss: 0.6214 - val_meanIoU: 0.4415 - learning_rate: 1.0000e-04
# Epoch 29/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.4879 - meanIoU: 0.4677 - val_loss: 0.5966 - val_meanIoU: 0.4642 - learning_rate: 1.0000e-04
# Epoch 30/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.4792 - meanIoU: 0.4650 - val_loss: 0.5927 - val_meanIoU: 0.4577 - learning_rate: 1.0000e-04
# Epoch 31/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.4956 - meanIoU: 0.4569 - val_loss: 0.6107 - val_meanIoU: 0.4529 - learning_rate: 1.0000e-04
# Epoch 32/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.4580 - meanIoU: 0.4740 - val_loss: 0.6282 - val_meanIoU: 0.4447 - learning_rate: 1.0000e-04
# Epoch 33/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.4653 - meanIoU: 0.4666 - val_loss: 0.6200 - val_meanIoU: 0.4497 - learning_rate: 1.0000e-04
# Epoch 34/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.4675 - meanIoU: 0.4674 - val_loss: 0.6068 - val_meanIoU: 0.4650 - learning_rate: 1.0000e-04
# Epoch 35/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.4566 - meanIoU: 0.4731 - val_loss: 0.6143 - val_meanIoU: 0.4511 - learning_rate: 1.0000e-04
# Epoch 36/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.4395 - meanIoU: 0.4787 - val_loss: 0.5833 - val_meanIoU: 0.4694 - learning_rate: 1.0000e-04
# Epoch 37/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.4625 - meanIoU: 0.4714 - val_loss: 0.5748 - val_meanIoU: 0.4780 - learning_rate: 1.0000e-04
# Epoch 38/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.4519 - meanIoU: 0.4740 - val_loss: 0.5764 - val_meanIoU: 0.4709 - learning_rate: 1.0000e-04
# Epoch 39/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.4032 - meanIoU: 0.4912 - val_loss: 0.5829 - val_meanIoU: 0.4783 - learning_rate: 1.0000e-04
# Epoch 40/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.4094 - meanIoU: 0.4883 - val_loss: 0.6131 - val_meanIoU: 0.4593 - learning_rate: 1.0000e-04
# Epoch 41/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.3959 - meanIoU: 0.4915 - val_loss: 0.6007 - val_meanIoU: 0.4641 - learning_rate: 1.0000e-04
# Epoch 42/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.3898 - meanIoU: 0.4958 - val_loss: 0.5874 - val_meanIoU: 0.4781 - learning_rate: 1.0000e-04
# Epoch 43/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.3866 - meanIoU: 0.4937 - val_loss: 0.6155 - val_meanIoU: 0.4648 - learning_rate: 1.0000e-04
# Epoch 44/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - loss: 0.3935 - meanIoU: 0.4977 - val_loss: 0.5962 - val_meanIoU: 0.4783 - learning_rate: 1.0000e-04
# Epoch 45/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - loss: 0.3568 - meanIoU: 0.5094 - val_loss: 0.5812 - val_meanIoU: 0.4797 - learning_rate: 1.0000e-05
# Epoch 46/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - loss: 0.3407 - meanIoU: 0.5145 - val_loss: 0.5729 - val_meanIoU: 0.4802 - learning_rate: 1.0000e-05
# Epoch 47/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.3341 - meanIoU: 0.5159 - val_loss: 0.5746 - val_meanIoU: 0.4781 - learning_rate: 1.0000e-05
# Epoch 48/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.3370 - meanIoU: 0.5119 - val_loss: 0.5759 - val_meanIoU: 0.4780 - learning_rate: 1.0000e-05
# Epoch 49/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.3532 - meanIoU: 0.5166 - val_loss: 0.5772 - val_meanIoU: 0.4782 - learning_rate: 1.0000e-05
# Epoch 50/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.3368 - meanIoU: 0.5184 - val_loss: 0.5833 - val_meanIoU: 0.4777 - learning_rate: 1.0000e-05
# Epoch 51/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.3261 - meanIoU: 0.5200 - val_loss: 0.5795 - val_meanIoU: 0.4766 - learning_rate: 1.0000e-05
# Epoch 52/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.3297 - meanIoU: 0.5160 - val_loss: 0.5885 - val_meanIoU: 0.4759 - learning_rate: 1.0000e-05
# Epoch 53/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.3285 - meanIoU: 0.5176 - val_loss: 0.5890 - val_meanIoU: 0.4779 - learning_rate: 1.0000e-05
# Epoch 54/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.3263 - meanIoU: 0.5168 - val_loss: 0.5865 - val_meanIoU: 0.4755 - learning_rate: 1.0000e-05
# Epoch 55/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.3289 - meanIoU: 0.5154 - val_loss: 0.5786 - val_meanIoU: 0.4777 - learning_rate: 1.0000e-05
# Epoch 56/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.3250 - meanIoU: 0.5141 - val_loss: 0.5781 - val_meanIoU: 0.4771 - learning_rate: 1.0000e-05

# %%
# Plot and display training and validation loss
plt.figure(figsize=(18, 3))
plt.plot(history['loss'], label='Training', alpha=0.8, color='#ff7f0e', linewidth=2)
plt.plot(history['val_loss'], label='Validation', alpha=0.9, color='#5a9aa5', linewidth=2)
plt.title('Cross Entropy')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# Plot and display training and validation accuracy
plt.figure(figsize=(18, 3))
plt.plot(history['meanIoU'], label='Training', alpha=0.8, color='#ff7f0e', linewidth=2)
plt.plot(history['val_meanIoU'], label='Validation', alpha=0.9, color='#5a9aa5', linewidth=2)
plt.title('Mean IoU')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ## Test Prediction and Final Evaluation

# %%
# Predict class probabilities and get predicted classes
test_predictions = model.predict(test_img_local, verbose=0)
test_predictions = np.argmax(test_predictions, axis=-1)
test_lbl_local = np.argmax(test_lbl_local, axis=-1)

# %%
# Calculate and display test set accuracy
test_accuracy = accuracy_score(test_lbl_local.flatten(), test_predictions.flatten())
print(f'Accuracy score over the test set: {round(test_accuracy, 4)}')

# Calculate and display test set precision
test_precision = precision_score(test_lbl_local.flatten(), test_predictions.flatten(), average='weighted', zero_division=0)
print(f'Precision score over the test set: {round(test_precision, 4)}')

# Calculate and display test set recall
test_recall = recall_score(test_lbl_local.flatten(), test_predictions.flatten(), average='weighted')
print(f'Recall score over the test set: {round(test_recall, 4)}')

# Calculate and display test set F1 score
test_f1 = f1_score(test_lbl_local.flatten(), test_predictions.flatten(), average='weighted')
print(f'F1 score over the test set: {round(test_f1, 4)}')

# Calculate and display test set mean Intersection Over Union score
# one_hot_pred = tfk.utils.to_categorical(test_predictions, num_classes=NUM_CLASSES)
test_miou = MeanIoU(NUM_CLASSES)
test_miou.update_state(test_lbl_local, test_predictions)
test_miou = test_miou.result().numpy()
print(f'Mean Intersection over Union over the test set: {round(test_miou, 4)}')
# Out:
# Accuracy score over the test set: 0.755
# Precision score over the test set: 0.7468
# Recall score over the test set: 0.755
# F1 score over the test set: 0.7436
# Mean Intersection over Union over the test set: 0.47769999504089355

# %% [markdown]
# ## Save

# %%
from datetime import datetime

current_time = datetime.now().strftime("%d|%m-%H:%M")

model_filename = f'UNet_{current_time}.keras'
print("Saved as :",model_filename)

# Storing the model, while ignoring the optimizer
model.save(f'models/{model_filename}', include_optimizer=False)
# Out:
# Saved as : UNet_14|12-12:47.keras

# %% [markdown]
# ## Submission

# %%
# Predict the masks for the submission
preds = model.predict(test_img)
preds = np.argmax(preds, axis=-1)
# Out:
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step

# %%
# Converts segmentation predictions into a DataFrame format for Kaggle
def y_to_df(y) -> pd.DataFrame:
    n_samples = len(y)
    y_flat = y.reshape(n_samples, -1)
    df = pd.DataFrame(y_flat)
    df["id"] = np.arange(n_samples)
    cols = ["id"] + [col for col in df.columns if col != "id"]
    return df[cols]

# %%
# Create and download the csv submission file
timestep_str = model_filename.replace("model_", "").replace(".keras", "")
submission_filename = f"submissions/submission_{timestep_str}.csv"
submission_df = y_to_df(preds)
submission_df.to_csv(submission_filename, index=False)
